# %%
import numpy as np

# %%
data = np.genfromtxt('StudentsPerformance.csv', delimiter=',', dtype=None, encoding='utf-8')

# %%
data
# Out:
# array([['"gender"', '"race/ethnicity"', '"parental level of education"',
#         ..., '"math score"', '"reading score"', '"writing score"'],
#        ['"female"', '"group B"', '"bachelor\'s degree"', ..., '"72"',
#         '"72"', '"74"'],
#        ['"female"', '"group C"', '"some college"', ..., '"69"', '"90"',
#         '"88"'],
#        ...,
#        ['"female"', '"group C"', '"high school"', ..., '"59"', '"71"',
#         '"65"'],
#        ['"female"', '"group D"', '"some college"', ..., '"68"', '"78"',
#         '"77"'],
#        ['"female"', '"group D"', '"some college"', ..., '"77"', '"86"',
#         '"86"']], shape=(1001, 8), dtype='<U29')

# %%
data[2,]
# Out:
# array(['"female"', '"group C"', '"some college"', '"standard"',
#        '"completed"', '"69"', '"90"', '"88"'], dtype='<U29')

# %%
arr = np.array(data)

# %%
arr
# Out:
# array([['"gender"', '"race/ethnicity"', '"parental level of education"',
#         ..., '"math score"', '"reading score"', '"writing score"'],
#        ['"female"', '"group B"', '"bachelor\'s degree"', ..., '"72"',
#         '"72"', '"74"'],
#        ['"female"', '"group C"', '"some college"', ..., '"69"', '"90"',
#         '"88"'],
#        ...,
#        ['"female"', '"group C"', '"high school"', ..., '"59"', '"71"',
#         '"65"'],
#        ['"female"', '"group D"', '"some college"', ..., '"68"', '"78"',
#         '"77"'],
#        ['"female"', '"group D"', '"some college"', ..., '"77"', '"86"',
#         '"86"']], shape=(1001, 8), dtype='<U29')

# %%
arr[:,7]
# Out:
# array(['"writing score"', '"74"', '"88"', ..., '"65"', '"77"', '"86"'],
#       shape=(1001,), dtype='<U29')
